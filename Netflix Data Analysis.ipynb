# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("Netflix Userbase.csv")
df.head()
# Out:
#    User ID Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 0        1             Basic               10  15-01-22          10-06-23
# 1        2           Premium               15  05-09-21          22-06-23
# 2        3          Standard               12  28-02-23          27-06-23
# 3        4          Standard               12  10-07-22          26-06-23
# 4        5             Basic               10  01-05-23          28-06-23
#
#           Country  Age  Gender      Device Plan Duration
# 0   United States   28    Male  Smartphone       1 Month
# 1          Canada   35  Female      Tablet       1 Month
# 2  United Kingdom   42    Male    Smart TV       1 Month
# 3       Australia   51  Female      Laptop       1 Month
# 4         Germany   33    Male  Smartphone       1 Month

# %% [markdown]
# * we work on netflix data were our analysis depend on age,country,gender,device and subscription type.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   User ID            2500 non-null   int64
#  1   Subscription Type  2500 non-null   object
#  2   Monthly Revenue    2500 non-null   int64
#  3   Join Date          2500 non-null   object
#  4   Last Payment Date  2500 non-null   object
#  5   Country            2500 non-null   object
#  6   Age                2500 non-null   int64
#  7   Gender             2500 non-null   object
#  8   Device             2500 non-null   object
#  9   Plan Duration      2500 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 195.4+ KB

# %%
df["Join Date"].astype("datetime64[ns]")
# Out:
# 0      2022-01-15
# 1      2021-05-09
# 2      2023-02-28
# 3      2022-10-07
# 4      2023-01-05
#           ...
# 2495   2022-07-25
# 2496   2022-04-08
# 2497   2022-09-08
# 2498   2022-12-08
# 2499   2022-08-13
# Name: Join Date, Length: 2500, dtype: datetime64[ns]

# %% [markdown]
# * The data type of the datetime column is a datetime64[ns] object. The [ns] means the nano second-based time format that specifies the accuracy of the DateTime object.
# * By using this we specifies the join date in that manner.

# %%
df["Join Date"]=df["Join Date"].astype("datetime64[ns]")

# %%
df["Join Date"].dtype
# Out:
# dtype('<M8[ns]')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   User ID            2500 non-null   int64
#  1   Subscription Type  2500 non-null   object
#  2   Monthly Revenue    2500 non-null   int64
#  3   Join Date          2500 non-null   datetime64[ns]
#  4   Last Payment Date  2500 non-null   object
#  5   Country            2500 non-null   object
#  6   Age                2500 non-null   int64
#  7   Gender             2500 non-null   object
#  8   Device             2500 non-null   object
#  9   Plan Duration      2500 non-null   object
# dtypes: datetime64[ns](1), int64(3), object(6)
# memory usage: 195.4+ KB

# %%
df["Last Payment Date"]=df["Last Payment Date"].astype("datetime64[ns]")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   User ID            2500 non-null   int64
#  1   Subscription Type  2500 non-null   object
#  2   Monthly Revenue    2500 non-null   int64
#  3   Join Date          2500 non-null   datetime64[ns]
#  4   Last Payment Date  2500 non-null   datetime64[ns]
#  5   Country            2500 non-null   object
#  6   Age                2500 non-null   int64
#  7   Gender             2500 non-null   object
#  8   Device             2500 non-null   object
#  9   Plan Duration      2500 non-null   object
# dtypes: datetime64[ns](2), int64(3), object(5)
# memory usage: 195.4+ KB

# %% [markdown]
# * we specifies the data type of join date and last payment date column is datetime64[ns] object.

# %%
df["Plan Duration"].value_counts()
# Out:
# Plan Duration
# 1 Month    2500
# Name: count, dtype: int64

# %% [markdown]
# * by this value_counts we counts the plan duration of 2500 rows.

# %%
df.drop("Plan Duration",axis=1,inplace=True)

# %% [markdown]
# * By drop() function we remove the "plan duration" column from DataFrame.

# %%
df.head()
# Out:
#    User ID Subscription Type  Monthly Revenue  Join Date Last Payment Date  \
# 0        1             Basic               10 2022-01-15        2023-10-06
# 1        2           Premium               15 2021-05-09        2023-06-22
# 2        3          Standard               12 2023-02-28        2023-06-27
# 3        4          Standard               12 2022-10-07        2023-06-26
# 4        5             Basic               10 2023-01-05        2023-06-28
#
#           Country  Age  Gender      Device
# 0   United States   28    Male  Smartphone
# 1          Canada   35  Female      Tablet
# 2  United Kingdom   42    Male    Smart TV
# 3       Australia   51  Female      Laptop
# 4         Germany   33    Male  Smartphone

# %%
# %matplotlib inline

plt.title("Subscription Type")
sns.countplot(df,x="Subscription Type",hue="Subscription Type")
plt.show()

# %% [markdown]
# * By using this we clearly count the subscriber according to basic, premium and standard subscription type.
# * The Basic subscription is more subscribed by the customer.
# * The Premium type subscription type is less subscribed by the customer.

# %%
print("Total Revenue",np.sum(df["Monthly Revenue"]))
# Out:
# Total Revenue 31271

# %% [markdown]
# * we calculate the total monthly revenue.

# %%
# %matplotlib inline
plt.title("John Date")
sns.histplot(df,x="Join Date",bins=10)
plt.show()

# %% [markdown]
# * By using thsi we plot the subscriber according to join date.

# %%
# %matplotlib inline
plt.title("John Date")
sns.histplot(df,x="Join Date",bins=10)
plt.xticks(rotation=90)
plt.show()

# %%
# %matplotlib inline
plt.title("John Date")
sns.histplot(df,x="Join Date",bins=20,kde=True)
plt.xticks(rotation=90)
plt.show()

# %%
plt.title("Join Date")
sns.histplot(df,x="Last Payment Date",bins=10,kde=True)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# * By using this we plot the count of subscriber according to Last payment date of subscription.

# %%
plt.title("Country")
sns.countplot(df,x="Country",hue="Country")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# * In this we plot the number of subscriber in perticular country.
# * the number of subscription in United states and Spain is more.

# %%
plt.title("Age")
sns.histplot(df,x="Age",bins=20,kde=True)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# * In this we plot the age wise subscription.
# * we see that the subscription 40-45 age group is more and 25-30 age group is less.

# %%
plt.title("Gender")
sns.countplot(df,x="Gender",hue="Subscription Type")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# * In this we plot the gender wise subscription type is specified.
# * By using this we clealy see that the male subscriber is more in Basic subscription type and less in premium subscription type.
# * The female subscriber are also more in Basic subscription type and less in premium type.

# %%
plt.title("Gender")
sns.countplot(df,x="Gender",hue="Country")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# * By using this we plot the the male and female subscriber in each country in data frame.
# * we clear that the in United states male subscriber are more and in brazil male subscriber are less.
# * In the spain the number of female subscriber are more and the number of female subscriber in maxico is less.

# %%
plt.title("Gender")
sns.countplot(df,x="Gender",hue="Country")
plt.legend(loc="upper left")
plt.xticks(rotation=90)
plt.show()

# %%
plt.title("Device")
sns.countplot(df,x="Device",hue="Device")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# * By using this we plot the bar of netflix subscription in that perticular devices.
# * BY this we clear that the subscription in laptop is more and less in smart tv.

# %%
count_sub_type=df["Subscription Type"].value_counts()
count_device=df["Device"].value_counts()
count_country=df["Country"].value_counts()
count_age=df["Age"].value_counts()
count_gender=df["Gender"].value_counts()

# %%
count_country
# Out:
# Country
# United States     451
# Spain             451
# Canada            317
# United Kingdom    183
# Australia         183
# Germany           183
# France            183
# Brazil            183
# Mexico            183
# Italy             183
# Name: count, dtype: int64

# %%
count_age
# Out:
# Age
# 39    116
# 30    116
# 28    115
# 31    115
# 41    114
# 47    111
# 37    107
# 35    105
# 29    104
# 40    103
# 42    102
# 48    101
# 46     99
# 36     99
# 49     97
# 43     94
# 33     93
# 51     93
# 32     92
# 45     89
# 38     89
# 34     88
# 27     87
# 44     86
# 50     84
# 26      1
# Name: count, dtype: int64

# %%
pd.crosstab(columns=df["Subscription Type"],index=df["Country"])
# Out:
# Subscription Type  Basic  Premium  Standard
# Country
# Australia             31      101        51
# Brazil               146       33         4
# Canada               145       88        84
# France                36      147         0
# Germany              149        3        31
# Italy                176        4         3
# Mexico                 4        0       179
# Spain                110      212       129
# United Kingdom         3        0       180
# United States        199      145       107

# %%
pd.crosstab(columns=df["Gender"],index=df["Country"])
# Out:
# Gender          Female  Male
# Country
# Australia           89    94
# Brazil              95    88
# Canada             157   160
# France              91    92
# Germany             94    89
# Italy               91    92
# Mexico              89    94
# Spain              233   218
# United Kingdom      93    90
# United States      225   226

# %%
pd.crosstab(columns=df["Subscription Type"],index=df["Gender"])
# Out:
# Subscription Type  Basic  Premium  Standard
# Gender
# Female               512      364       381
# Male                 487      369       387

# %%
count_age.sort_index()
# Out:
# Age
# 26      1
# 27     87
# 28    115
# 29    104
# 30    116
# 31    115
# 32     92
# 33     93
# 34     88
# 35    105
# 36     99
# 37    107
# 38     89
# 39    116
# 40    103
# 41    114
# 42    102
# 43     94
# 44     86
# 45     89
# 46     99
# 47    111
# 48    101
# 49     97
# 50     84
# 51     93
# Name: count, dtype: int64

# %%
pd.cut(df["Age"],bins=5,labels=["26-30","31-35","36-40","41-45","45-More"])

# %%
df["Age Group"]=pd.cut(df["Age"],bins=5,labels=["26-30","31-35","36-40","41-45","45-More"])

# %% [markdown]
# * By this we add the age group column acording to age .

# %%
df.head()
# Out:
#    User ID Subscription Type  Monthly Revenue  Join Date Last Payment Date  \
# 0        1             Basic               10 2022-01-15        2023-10-06
# 1        2           Premium               15 2021-05-09        2023-06-22
# 2        3          Standard               12 2023-02-28        2023-06-27
# 3        4          Standard               12 2022-10-07        2023-06-26
# 4        5             Basic               10 2023-01-05        2023-06-28
#
#           Country  Age  Gender      Device Age Group
# 0   United States   28    Male  Smartphone     26-30
# 1          Canada   35  Female      Tablet     31-35
# 2  United Kingdom   42    Male    Smart TV     41-45
# 3       Australia   51  Female      Laptop   45-More
# 4         Germany   33    Male  Smartphone     31-35

# %%
pd.crosstab(columns=df["Subscription Type"],index=df["Age Group"])
# Out:
# Subscription Type  Basic  Premium  Standard
# Age Group
# 26-30                224      171       143
# 31-35                175      150       152
# 36-40                212      144       173
# 41-45                193      129       148
# 45-More              195      139       152

# %%
sns.heatmap(pd.crosstab(columns=df["Subscription Type"],index=df["Age Group"]),annot=True,
           fmt="d")
plt.show()

# %% [markdown]
# * By using this we can clearly see that the basic subscription is more often subscribe by 26-30 age group.
# *
# In 41-45 age group the subscription is less compare to otherand that is primium type.

# %%
sns.heatmap(pd.crosstab(columns=df["Subscription Type"],index=df["Device"]),annot=True,
           fmt="d")
plt.show()

# %% [markdown]
#  * By using this we can clearly see that the basic subscription is more often subscribe in laptop.
#  * In  smartphone the subscription is less compare to other and that is primium type.
